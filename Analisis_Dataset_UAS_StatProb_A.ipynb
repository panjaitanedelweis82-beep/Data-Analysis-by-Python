# %% [markdown]
# <a href="https://colab.research.google.com/github/panjaitanedelweis82-beep/Data-Analysis-by-Python/blob/main/Analisis_Dataset_UAS_StatProb_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_excel("/content/drive/MyDrive/Global Super Store /UAS Statistika dan Probabilitas.xlsx")
print(data.head(6))
# Out:
#    Row ID         Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0   42433     AG-2011-2040 2011-01-01 2011-01-06  Standard Class    TB-11280
# 1   22253    IN-2011-47883 2011-01-01 2011-01-08  Standard Class    JH-15985
# 2   48883     HU-2011-1220 2011-01-01 2011-01-05    Second Class      AT-735
# 3   11731  IT-2011-3647632 2011-01-01 2011-01-05    Second Class    EM-14140
# 4   22255    IN-2011-47883 2011-01-01 2011-01-08  Standard Class    JH-15985
# 5   22254    IN-2011-47883 2011-01-01 2011-01-08  Standard Class    JH-15985
#
#      Customer Name      Segment         City            State  ...  \
# 0  Toby Braunhardt     Consumer  Constantine      Constantine  ...
# 1      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
# 2    Annie Thurman     Consumer     Budapest         Budapest  ...
# 3     Eugene Moren  Home Office    Stockholm        Stockholm  ...
# 4      Joseph Holt     Consumer  Wagga Wagga  New South Wales  ...
# ...

# %%
print("\n 6 Data Terakhir")
print(data.tail(6))
# Out:
#  6 Data Terakhir
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 51284    2143  MX-2014-108574 2014-12-31 2015-01-04  Standard Class
# 51285   32593  CA-2014-115427 2014-12-31 2015-01-04  Standard Class
# 51286   47594    MO-2014-2560 2014-12-31 2015-01-05  Standard Class
# 51287    8857  MX-2014-110527 2014-12-31 2015-01-02    Second Class
# 51288    6852  MX-2014-114783 2014-12-31 2015-01-06  Standard Class
# 51289   36388  CA-2014-156720 2014-12-31 2015-01-04  Standard Class
#
#       Customer ID     Customer Name      Segment       City             State  \
# 51284    JB-16045     Julia Barnett  Home Office    Reynosa        Tamaulipas
# 51285    EB-13975        Erica Bern    Corporate  Fairfield        California
# 51286     LP-7095         Liz Preis     Consumer     Agadir  Souss-Massa-Draâ
# 51287    CM-12190  Charlotte Melton     Consumer    Managua           Managua
# 51288    TD-20995     Tamara Dahlen     Consumer     Juárez         Chihuahua
# ...

# %%
print("\n Struktur Data")
print(data.info())
# Out:
#  Struktur Data
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %%
print("\n Ringkasan Statistik Awal")
print(data.describe(include='all'))
# Out:
#  Ringkasan Statistik Awal
#              Row ID        Order ID                     Order Date  \
# count   51290.00000           51290                          51290
# unique          NaN           25035                            NaN
# top             NaN  CA-2014-100111                            NaN
# freq            NaN              14                            NaN
# mean    25645.50000             NaN  2013-05-11 21:26:49.155780864
# min         1.00000             NaN            2011-01-01 00:00:00
# 25%     12823.25000             NaN            2012-06-19 00:00:00
# 50%     25645.50000             NaN            2013-07-08 00:00:00
# 75%     38467.75000             NaN            2014-05-22 00:00:00
# max     51290.00000             NaN            2014-12-31 00:00:00
# std     14806.29199             NaN                            NaN
#
#                             Ship Date       Ship Mode Customer ID  \
# count                           51290           51290       51290
# ...

# %%
print("\n Jumlah Baris dan Kolom")
print(data.shape)
# Out:
#  Jumlah Baris dan Kolom
# (51290, 24)

# %%
mean_sales = data.mean(numeric_only=True)
print("\n Rata-Rata")
print(mean_sales)
# Out:
#  Rata-Rata
# Row ID            25645.500000
# Postal Code       55190.379428
# Sales            623187.338331
# Quantity              3.476545
# Discount              4.370014
# Profit            89216.583993
# Shipping Cost      2404.637688
# dtype: float64

# %%
min_sales = data.min(numeric_only=True)
print("\n Minimum")
print(min_sales)

max_sales = data.max(numeric_only=True)
print("\n Maksimum")
print(max_sales)

median_sales = data.median(numeric_only=True)
print("\n Median")
print(median_sales)

std_sales = data.std(numeric_only=True)
print("\n Standar Deviasi")
print(std_sales)

q1_sales = data['Sales'].quantile(0.25)
print("Kuartil 1 :", q1_sales)


q3_sales = data['Sales'].quantile(0.75)
print("Kuartil 3 :", q3_sales)
# Out:
#  Minimum
# Row ID                  1.0
# Postal Code          1040.0
# Sales                   3.0
# Quantity                1.0
# Discount                0.0
# Profit          -91671776.0
# Shipping Cost           0.0
# dtype: float64
#
#  Maksimum
# Row ID               51290.0
# Postal Code          99301.0
# Sales            190210816.0
# Quantity                14.0
# Discount               602.0
# Profit            87282816.0
# Shipping Cost        93357.0
# dtype: float64
#
#  Median
# Row ID           25645.5
# Postal Code      56430.5
# Sales            12550.5
# Quantity             3.0
# Discount             0.0
# Profit            1161.0
# Shipping Cost      646.0
# dtype: float64
#
#  Standar Deviasi
# Row ID           1.480629e+04
# Postal Code      3.206369e+04
# Sales            5.462623e+06
# Quantity         2.278766e+00
# Discount         2.401600e+01
# Profit           1.814242e+06
# Shipping Cost    5.535589e+03
# dtype: float64
# Kuartil 1 : 3092.0
# ...

# %%
top_10_biggest = data.groupby('Order ID')['Sales'].sum().reset_index()
top_10_biggest= top_10_biggest.sort_values(by='Sales', ascending=False).head(10)
print(top_10_biggest.to_string(index=False), "\n")
# Out:
#       Order ID     Sales
# MX-2014-158386 191126545
# MX-2012-102848 190262286
# US-2011-152821 177074692
# MX-2014-133473 175762744
# MX-2014-139591 169278136
# MX-2013-169096 168590144
# MX-2014-127656 165598780
# MX-2014-166905 164925488
# MX-2014-127264 152348220
# MX-2011-136399 151647496

# %%
top_10_smallest = data.groupby('Order ID')['Sales'].sum().reset_index()
top_10_smallest = top_10_smallest.sort_values(by='Sales', ascending=True).head(10)
print(top_10_smallest.to_string(index=False), "\n")
# Out:
#       Order ID  Sales
# CA-2013-111409      3
#   SA-2013-4930      6
# CA-2014-154718      6
# CA-2013-161158      8
# MX-2014-106719      8
#   TU-2013-6840      9
#   IR-2013-1050      9
#   PL-2013-5180      9
# MX-2013-117793     14
# MX-2012-117870     16

# %%
kolom_transaksi = ['Ship Mode', 'Segment', 'Region', 'Category', 'Sub-Category', 'Order Priority']

for sell in kolom_transaksi:
    print(f"\nJumlah transaksi berdasarkan '{sell}':")
    print(data[sell].value_counts())
print("\n" + "="*50 + "\n")
# Out:
# Jumlah transaksi berdasarkan 'Ship Mode':
# Ship Mode
# Standard Class    30775
# Second Class      10309
# First Class        7505
# Same Day           2701
# Name: count, dtype: int64
#
# Jumlah transaksi berdasarkan 'Segment':
# Segment
# Consumer       26518
# Corporate      15429
# Home Office     9343
# Name: count, dtype: int64
#
# Jumlah transaksi berdasarkan 'Region':
# Region
# Central           11117
# South              6645
# EMEA               5029
# North              4785
# Africa             4587
# Oceania            3487
# West               3203
# Southeast Asia     3129
# East               2848
# North Asia         2338
# Central Asia       2048
# Caribbean          1690
# Canada              384
# Name: count, dtype: int64
#
# Jumlah transaksi berdasarkan 'Category':
# Category
# Office Supplies    31273
# Technology         10141
# Furniture           9876
# Name: count, dtype: int64
#
# Jumlah transaksi berdasarkan 'Sub-Category':
# Sub-Category
# ...

# %%
for kolom in kolom_kategori:
    print(f"\nTotal Penjualan berdasarkan {kolom}")
    print(data.groupby(kolom)['Sales'].sum())
# Out:
# Total Penjualan berdasarkan Ship Mode
# Ship Mode
# First Class        4844199135
# Same Day           1372557552
# Second Class       6327057493
# Standard Class    19419464403
# Name: Sales, dtype: int64
#
# Total Penjualan berdasarkan Segment
# Segment
# Consumer       17110041222
# Corporate       9293273958
# Home Office     5559963403
# Name: Sales, dtype: int64
#
# Total Penjualan berdasarkan Region
# Region
# Africa             112215414
# Canada               5469717
# Caribbean         3553419638
# Central           7681707830
# Central Asia        87013911
# EMEA               159170760
# East               292543756
# North             7479036411
# North Asia         117490251
# Oceania            746809854
# South             6254355661
# Southeast Asia    5108707737
# West               365337643
# Name: Sales, dtype: int64
#
# Total Penjualan berdasarkan Category
# Category
# Furniture           3583649617
# Office Supplies     2528467705
# ...

# %%
kolom_numerik = [
    'Quantity',
    'Discount',
    'Profit',
    'Shipping Cost'
]

hasil_statistik = data[kolom_numerik].agg(
    ['sum', 'mean', 'min', 'max']
)

print("\nStatistik Kolom Numerik")
print(hasil_statistik)
# Out:
# Statistik Kolom Numerik
#            Quantity       Discount        Profit  Shipping Cost
# sum   178312.000000  224138.000000  4.575919e+09   1.233339e+08
# mean       3.476545       4.370014  8.921658e+04   2.404638e+03
# min        1.000000       0.000000 -9.167178e+07   0.000000e+00
# max       14.000000     602.000000  8.728282e+07   9.335700e+04

# %%
top_city = data.groupby('City')['Sales'].sum().sort_values(ascending=False).head(5)
print("5 Kota dengan Total Penjualan Terbesar")
print(top_city)
# Out:
# 5 Kota dengan Total Penjualan Terbesar
# City
# Mexico City     993630258
# San Salvador    864251989
# Jakarta         721756380
# Morelia         705068503
# São Paulo       612729896
# Name: Sales, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=top_city.values, y=top_city.index)
plt.title('Top 5 Kota dengan Total Penjualan Terbesar')
plt.xlabel('Total Sales')
plt.ylabel('City')
plt.show()

# %%
top_state = data.groupby('State')['Sales'].sum().sort_values(ascending=False).head(5)
print("\n5 State/Provinsi dengan Total Penjualan Terbesar")
print(top_state)
# Out:
# 5 State/Provinsi dengan Total Penjualan Terbesar
# State
# San Salvador        1520752339
# Distrito Federal    1373341906
# Guatemala           1214302927
# São Paulo           1041115742
# Jawa Barat           751566882
# Name: Sales, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=top_state.values, y=top_state.index)
plt.title('Top 5 State/Provinsi dengan Total Penjualan Terbesar')
plt.xlabel('Total Sales')
plt.ylabel('State')
plt.show()

# %%
region_sales = data.groupby('Region')['Sales'].sum()
print(region_sales)
# Out:
# Region
# Africa             112215414
# Canada               5469717
# Caribbean         3553419638
# Central           7681707830
# Central Asia        87013911
# EMEA               159170760
# East               292543756
# North             7479036411
# North Asia         117490251
# Oceania            746809854
# South             6254355661
# Southeast Asia    5108707737
# West               365337643
# Name: Sales, dtype: int64

# %%
region_sales.plot(kind='bar')
plt.title('Total Penjualan Berdasarkan Region')
plt.xlabel('Region')
plt.ylabel('Total Penjualan')
plt.show()

# %%
profit_region = data.groupby('Region')['Profit'].sum().sort_values(ascending=False)
print("\nTotal Profit Berdasarkan Region")
print(profit_region)
# Out:
# Total Profit Berdasarkan Region
# Region
# North             1574891239
# Central            729330709
# West               715162034
# East               653372827
# Caribbean          536618775
# South              499712302
# Oceania             64463415
# North Asia           3557361
# Central Asia         3241996
# Canada               1366317
# Africa             -56975943
# Southeast Asia     -62325854
# EMEA               -86496585
# Name: Profit, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=profit_region.index, y=profit_region.values)
plt.title('Total Profit Berdasarkan Region')
plt.xlabel('Region')
plt.ylabel('Total Profit')
plt.show()

# %%
category_sales = data.groupby('Category')['Sales'].sum()
print(category_sales)
# Out:
# Category
# Furniture           3583649617
# Office Supplies     2528467705
# Technology         25851161261
# Name: Sales, dtype: int64

# %%
category_sales.plot(kind='bar')
plt.title('Total Penjualan Berdasarkan Category')
plt.xlabel('Category')
plt.ylabel('Total Penjualan')
plt.show()

# %%
sub_top = data.groupby('Sub-Category')['Sales'].sum().sort_values(ascending=False).head(5)
print(sub_top)
# Out:
# Sub-Category
# Copiers      23319431708
# Phones        1378953610
# Bookcases     1262471095
# Chairs        1144451471
# Tables         919102642
# Name: Sales, dtype: int64

# %%
sub_top.plot(kind='bar')
plt.title('5 Sub-Category dengan Total Penjualan Terbesar')
plt.xlabel('Sub-Category')
plt.ylabel('Total Penjualan')
plt.show()

# %%
print(data.groupby('Category')['Sales'].mean())
# Out:
# Category
# Furniture          3.628645e+05
# Office Supplies    8.085146e+04
# Technology         2.549173e+06
# Name: Sales, dtype: float64

# %%
print(data.groupby('Sub-Category')['Sales'].mean())
# Out:
# Sub-Category
# Accessories    1.194861e+05
# Appliances     5.184869e+05
# Art            3.612528e+04
# Binders        3.999520e+04
# Bookcases      5.236297e+05
# Chairs         3.332707e+05
# Copiers        1.049007e+07
# Envelopes      4.297642e+04
# Fasteners      2.284360e+04
# Furnishings    8.126953e+04
# Labels         1.717962e+04
# Machines       5.285035e+05
# Paper          3.257721e+04
# Phones         4.107696e+05
# Storage        1.464206e+05
# Supplies       5.582424e+04
# Tables         1.067483e+06
# Name: Sales, dtype: float64

# %%
print(data.groupby('Category')['Quantity'].sum())
# Out:
# Category
# Furniture           34954
# Office Supplies    108182
# Technology          35176
# Name: Quantity, dtype: int64

# %%
print(data.groupby('Sub-Category')['Quantity'].sum())
# Out:
# Sub-Category
# Accessories    10946
# Appliances      6078
# Art            16301
# Binders        21429
# Bookcases       8310
# Chairs         12336
# Copiers         7454
# Envelopes       8380
# Fasteners       8390
# Furnishings    11225
# Labels          9322
# Machines        4906
# Paper          12822
# Phones         11870
# Storage        16917
# Supplies        8543
# Tables          3083
# Name: Quantity, dtype: int64

# %%
print(data.groupby('Category')['Profit'].sum())
# Out:
# Category
# Furniture          -183214363
# Office Supplies     767291338
# Technology         3991841618
# Name: Profit, dtype: int64

# %%
print(data.groupby('Sub-Category')['Profit'].sum())
# Out:
# Sub-Category
# Accessories     168797620
# Appliances      182535265
# Art              24797208
# Binders         178244162
# Bookcases        -8568975
# Chairs          116549728
# Copiers        3361592012
# Envelopes        27100802
# Fasteners        -7791608
# Furnishings      90809814
# Labels           32192718
# Machines         73330720
# Paper           204006691
# Phones          388121266
# Storage         175905049
# Supplies        -49698949
# Tables         -382004930
# Name: Profit, dtype: int64

# %%
ship_sales = data.groupby('Ship Mode')['Sales'].sum()
ship_sales.plot(kind='bar')
plt.title('Total Penjualan Berdasarkan Ship Mode')
plt.xlabel('Ship Mode')
plt.ylabel('Total Penjualan')
plt.show()

# %%
segment_sales = data.groupby('Segment')['Sales'].sum()
segment_sales.plot(kind='bar')
plt.title('Total Penjualan Berdasarkan Segment')
plt.xlabel('Segment')
plt.ylabel('Total Penjualan')
plt.show()

# %%
region_sales.plot(kind='bar')
plt.title('Total Penjualan Berdasarkan Region')
plt.xlabel('Region')
plt.ylabel('Total Penjualan')
plt.show()

# %%
category_sales.plot(kind='bar')
plt.title('Total Penjualan Berdasarkan Category')
plt.xlabel('Category')
plt.ylabel('Total Penjualan')
plt.show()

# %%
priority_sales = data.groupby('Order Priority')['Sales'].sum()
priority_sales.plot(kind='bar')
plt.title('Total Penjualan Berdasarkan Order Priority')
plt.xlabel('Order Priority')
plt.ylabel('Total Penjualan')
plt.show()

# %%
pivot1 = data.pivot_table(values='Sales',
index='Region',columns='Category',aggfunc='sum')
pivot1.plot(kind='bar')
plt.title('Penjualan Berdasarkan Region dan Category')
plt.ylabel('Total Penjualan')
plt.show()

# %%
pivot2 = data.pivot_table(values='Sales',
index='Ship Mode',columns='Category',aggfunc='sum')
pivot2.plot(kind='bar')
plt.title('Penjualan Berdasarkan Ship Mode dan Category')
plt.ylabel('Total Penjualan')
plt.show()

# %%
pivot3 = data.pivot_table(values='Sales',index='Segment',columns='Category',
aggfunc='sum')
pivot3.plot(kind='bar')
plt.title('Penjualan Berdasarkan Segment dan Category')
plt.ylabel('Total Penjualan')
plt.show()

# %%
priority_profit = data.groupby('Order Priority')['Profit'].sum()
priority_profit.plot(kind='bar')
plt.title('Total Profit Berdasarkan Order Priority')
plt.xlabel('Order Priority')
plt.ylabel('Profit')
plt.show()
